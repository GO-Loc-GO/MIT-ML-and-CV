# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import os
import cv2
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import tensorflow_addons as tfa
from tensorflow import keras
from tensorflow.keras import layers
import skimage.measure
import albumentations as A
import pandas as pd

# %%
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession

config = ConfigProto()
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)

# %%
# 加载数据集
kittiL = cv2.imread('data_scene_flow/training/image_2/000001_10.png')[:,:,::-1]
kittiDL = skimage.measure.block_reduce(cv2.imread('data_scene_flow/training/disp_noc_0/000001_10.png', 0), (8, 8), np.max)

# %%
# 数据集可视化
fig = plt.figure(figsize=(20,5))
plt.subplot(121),plt.imshow(kittiL),plt.title(f'Left {kittiL.shape}');
plt.subplot(122),plt.imshow(kittiDL),plt.title(f'Disparity {kittiDL.shape}');
plt.setp(fig.get_axes(), xticks=[], yticks=[]);

# %%
# 为在GPU上进行数据训练，构建数据加载管道
list_ds = tf.data.Dataset.list_files('data_scene_flow/training/image_2/*_10.png')

def process_path(file_path, seed):
    parts = tf.strings.split(file_path, os.sep)
    label_file = tf.strings.join([parts[0], parts[1],'disp_noc_0', parts[3]], os.sep)  # 这里的原程序的有误，文件路径错误

    # Make a new seed so that random transformation is consistent between image
    # and label depth map
    new_seed = tf.random.experimental.stateless_split(seed, num=1)[0, :]
  
    image = tf.io.read_file(file_path)
    image = tf.image.decode_png(image)
    image = tf.image.convert_image_dtype(image, tf.float32)
    image = tf.image.resize(image, [192, 640])
    image = tf.image.stateless_random_brightness(image, max_delta=0.3, seed=new_seed)
    image = tf.clip_by_value(image, 0, 1)
    image = tf.image.stateless_random_flip_left_right(image, seed=seed)
    image.set_shape((192, 640, 3))

    disp = tf.io.read_file(label_file)
    disp = tf.image.decode_png(disp)
    disp = tf.image.convert_image_dtype(disp, tf.float32)
    disp = tf.nn.max_pool2d(tf.expand_dims(disp, 0), (8, 8), 8, 'VALID')
    disp = tf.image.stateless_random_flip_left_right(disp, seed=seed)
    disp = tf.image.flip_left_right(disp)
    disp = tf.image.resize(disp, size=(48, 160))
    disp = tf.squeeze(disp)
    disp = disp * 255.0
    disp.set_shape((48, 160))

    rot_factor = tf.random.uniform(shape=[], minval=-7.0, maxval=7.0, dtype=tf.float32)
    angle = np.pi/180*rot_factor
    image = tfa.image.rotate(image, angle, fill_mode='nearest')
    disp = tfa.image.rotate(disp, angle, fill_mode='nearest')

    return image, disp


counter = tf.data.experimental.Counter()
train_ds = tf.data.Dataset.zip((list_ds, (counter, counter)))
validation_files = train_ds.take(10)
train_ds = train_ds.skip(10)

labeled_ds = train_ds.map(process_path, num_parallel_calls=4)
labeled_ds = labeled_ds.batch(32, drop_remainder=True).prefetch(buffer_size=32).repeat()

val_ds = validation_files.map(process_path).batch(5)

# %%
# 可视化训练数据
fig= plt.figure(figsize=(20, 20))
for i_f, f in enumerate(labeled_ds.take(1)):
    for i in range(10):
        plt.subplot(10,4,i_f*10 + 2*i + 1),plt.imshow(f[0][i].numpy()),plt.colorbar();
        plt.subplot(10,4,i_f*10 + 2*i + 2),plt.imshow(f[1][i].numpy()),plt.colorbar();

# %%
# 可视化测试数据
fig= plt.figure(figsize=(20, 20))
for i_f, f in enumerate(val_ds.take(1)):
    for i in range(2):
        plt.subplot(10,4,i_f*2 + 2*i + 1),plt.imshow(f[0][i].numpy());
        plt.subplot(10,4,i_f*2 + 2*i + 2),plt.imshow(f[1][i].numpy());

# %%
# 模型的建立
def make_model():
    inputs = keras.Input(shape=(192, 640, 3))

    # "Coarse" stream

    # encoder
    Coarse1_conv = keras.layers.Conv2D(96, (11, 11), (4, 4))(inputs)
    Coarse1_bn   = keras.layers.BatchNormalization()(Coarse1_conv)
    Coarse1_act  = keras.layers.ReLU()(Coarse1_bn)
    Coarse1      = keras.layers.MaxPool2D((2, 2))(Coarse1_act)

    Coarse2_conv = keras.layers.Conv2D(256, (5, 5), (2, 2))(Coarse1)
    Coarse2_bn   = keras.layers.BatchNormalization()(Coarse2_conv)
    Coarse2      = keras.layers.ReLU()(Coarse2_bn)

    Coarse3_conv = keras.layers.Conv2D(384, (3, 3))(Coarse2)
    Coarse3_bn   = keras.layers.BatchNormalization()(Coarse3_conv)
    Coarse3_act  = keras.layers.ReLU()(Coarse3_bn)
    Coarse3      = keras.layers.MaxPool2D((2, 2))(Coarse3_act)

    # decoder

    Coarse4_conv = keras.layers.Conv2DTranspose(256, (3, 3))(Coarse3)
    Coarse4_bn   = keras.layers.BatchNormalization()(Coarse4_conv)
    Coarse4_us   = keras.layers.UpSampling2D((2, 2))(Coarse4_bn)
    Coarse4      = keras.layers.ReLU()(Coarse4_us)

    Coarse5_conv = keras.layers.Conv2DTranspose(96, (3, 3), padding='same')(Coarse4)
    Coarse5_bn   = keras.layers.BatchNormalization()(Coarse5_conv)
    Coarse5_us   = keras.layers.UpSampling2D((2, 2))(Coarse5_bn)
    Coarse5      = keras.layers.ReLU()(Coarse5_us)

    Coarse6_conv = keras.layers.Conv2DTranspose(64, (3, 3), padding='same')(Coarse5)
    Coarse6_bn   = keras.layers.BatchNormalization()(Coarse6_conv)
    Coarse6_us   = keras.layers.UpSampling2D((2, 2))(Coarse6_bn)
    Coarse6      = keras.layers.ReLU()(Coarse6_us)

    # "Fine" stream
    Fine1_conv = keras.layers.Conv2D(64, (9, 9), (2, 2), padding='same')(inputs)
    Fine1_bn   = keras.layers.BatchNormalization()(Fine1_conv)
    Fine1_act  = keras.layers.ReLU()(Fine1_bn)
    Fine1      = keras.layers.MaxPool2D((2, 2))(Fine1_act)

    # add coarse output in ...
    Fine2_in   = tf.concat([Fine1, Coarse6], 3)
    Fine2_conv = keras.layers.Conv2D(64, (5, 5), padding='same')(Fine2_in)
    Fine2_bn   = keras.layers.BatchNormalization()(Fine2_conv)
    Fine2      = keras.layers.ReLU()(Fine2_bn)

    Fine3_conv = keras.layers.Conv2D(64, (5, 5), padding='same')(Fine2)
    Fine3_bn   = keras.layers.BatchNormalization()(Fine3_conv)
    Fine3      = keras.layers.ReLU()(Fine3_bn)

    Fine4      = keras.layers.Conv2D(1, (3, 3), activation='linear', padding='same')(Fine3)

    # padding to keep shape (48, 160)

    outputs = Fine4

    return keras.Model(inputs, outputs)

# %%
# 损失函数的定义
def eigen_2015_loss(y_true, y_pred):
    y_true = tf.cast(y_true, dtype=float)
    y_pred = tf.cast(y_pred, dtype=float)

    # Calculate d from y_true and y_pred
    # d = ...
    d = tf.where(tf.greater(y_true, 0), y_pred - tf.math.log(y_true), y_pred)
    valid = tf.where(tf.greater(y_true, 0), True, False)
    
    # Get `n` from `y_true`. Don't forget to tf.cast to tf.float32
    # n = ...
    n = tf.math.count_nonzero(y_true, axis=[1, 2])
    n = tf.cast(n, float)
    
    # Calculate data term
    # data_term = ...
    data_term = tf.reduce_sum(tf.square(d), axis=[1, 2])
    data_term = tf.divide(data_term, n)
    
    # Calculate direction term
    # direction_term = ...
    direction_term = tf.reduce_sum(d, axis=[1, 2])
    direction_term = tf.square(direction_term)
    direction_term = -tf.divide(direction_term, 2 * tf.square(n))
    
    # Calculate gradient matching term
    # matching_term = ...

    d_di = d[:,1:,:] - d[:,:-1,:]
    d_dj = d[:,:,1:] - d[:,:,:-1]
    valid_di = tf.cast(tf.logical_and(valid[:,1:,:], valid[:,:-1,:]), float)
    valid_dj = tf.cast(tf.logical_and(valid[:,:,1:], valid[:,:,:-1]), float)
    ni = tf.reduce_sum(valid_di, axis=[1, 2])
    nj = tf.reduce_sum(valid_dj, axis=[1, 2])
    matching_term = tf.divide(tf.reduce_sum(valid_di * tf.square(d_di), axis=[1, 2]), ni) + tf.divide(tf.reduce_sum(valid_dj * tf.square(d_dj), axis=[1, 2]), nj)

    return data_term + direction_term + matching_term

# %%
epochs = 150
learning_rate = 1e-3

batchsize = 32

steps_per_epoch = 20

model = make_model()

model.summary()  # 输出模型参数 

model.compile(loss=eigen_2015_loss, optimizer=keras.optimizers.Adam(lr=learning_rate), metrics=['accuracy'])
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 192, 640, 3) 0
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 46, 158, 96)  34944       input_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 46, 158, 96)  384         conv2d_7[0][0]
# __________________________________________________________________________________________________
# re_lu_9 (ReLU)                  (None, 46, 158, 96)  0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 23, 79, 96)   0           re_lu_9[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 10, 38, 256)  614656      max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 10, 38, 256)  1024        conv2d_8[0][0]
# __________________________________________________________________________________________________
# re_lu_10 (ReLU)                 (None, 10, 38, 256)  0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 8, 36, 384)   885120      re_lu_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 8, 36, 384)   1536        conv2d_9[0][0]
# __________________________________________________________________________________________________
# re_lu_11 (ReLU)                 (None, 8, 36, 384)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 4, 18, 384)   0           re_lu_11[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 6, 20, 256)   884992      max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 6, 20, 256)   1024        conv2d_transpose_3[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 12, 40, 256)  0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# re_lu_12 (ReLU)                 (None, 12, 40, 256)  0           up_sampling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 12, 40, 96)   221280      re_lu_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 12, 40, 96)   384         conv2d_transpose_4[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_4 (UpSampling2D)  (None, 24, 80, 96)   0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# re_lu_13 (ReLU)                 (None, 24, 80, 96)   0           up_sampling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 96, 320, 64)  15616       input_2[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_5 (Conv2DTrans (None, 24, 80, 64)   55360       re_lu_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 96, 320, 64)  256         conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 24, 80, 64)   256         conv2d_transpose_5[0][0]
# __________________________________________________________________________________________________
# re_lu_15 (ReLU)                 (None, 96, 320, 64)  0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_5 (UpSampling2D)  (None, 48, 160, 64)  0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 48, 160, 64)  0           re_lu_15[0][0]
# __________________________________________________________________________________________________
# re_lu_14 (ReLU)                 (None, 48, 160, 64)  0           up_sampling2d_5[0][0]
# __________________________________________________________________________________________________
# tf.concat_1 (TFOpLambda)        (None, 48, 160, 128) 0           max_pooling2d_5[0][0]
#                                                                  re_lu_14[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 48, 160, 64)  204864      tf.concat_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 48, 160, 64)  256         conv2d_11[0][0]
# __________________________________________________________________________________________________
# re_lu_16 (ReLU)                 (None, 48, 160, 64)  0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 48, 160, 64)  102464      re_lu_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 48, 160, 64)  256         conv2d_12[0][0]
# __________________________________________________________________________________________________
# re_lu_17 (ReLU)                 (None, 48, 160, 64)  0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 48, 160, 1)   577         re_lu_17[0][0]
# ==================================================================================================
# Total params: 3,025,249
# Trainable params: 3,022,561
# Non-trainable params: 2,688
# __________________________________________________________________________________________________

# %%
# 模型训练
callbacks = keras.callbacks.ModelCheckpoint(filepath='save_best.h5', verbose=1, save_best_only=True)

history = model.fit(labeled_ds, epochs=epochs, steps_per_epoch=steps_per_epoch, validation_data=val_ds, callbacks=callbacks, verbose=1, shuffle=True)
# Out:
# Epoch 1/150
# 20/20 [==============================] - 10s 393ms/step - loss: 2.5028 - accuracy: 0.3489 - val_loss: 109.9578 - val_accuracy: 0.3865
#
# Epoch 00001: val_loss improved from inf to 109.95781, saving model to save_best.h5
# Epoch 2/150
# 20/20 [==============================] - 8s 387ms/step - loss: 1.3781 - accuracy: 0.2767 - val_loss: 24.4271 - val_accuracy: 0.3852
#
# Epoch 00002: val_loss improved from 109.95781 to 24.42707, saving model to save_best.h5
# Epoch 3/150
# 20/20 [==============================] - 8s 394ms/step - loss: 1.3467 - accuracy: 0.3186 - val_loss: 6.1550 - val_accuracy: 0.3867
#
# Epoch 00003: val_loss improved from 24.42707 to 6.15497, saving model to save_best.h5
# Epoch 4/150
# 20/20 [==============================] - 8s 381ms/step - loss: 1.3200 - accuracy: 0.3204 - val_loss: 2.9460 - val_accuracy: 0.3786
#
# Epoch 00004: val_loss improved from 6.15497 to 2.94598, saving model to save_best.h5
# Epoch 5/150
# 20/20 [==============================] - 8s 387ms/step - loss: 1.3066 - accuracy: 0.3221 - val_loss: 2.0133 - val_accuracy: 0.3657
#
# Epoch 00005: val_loss improved from 2.94598 to 2.01330, saving model to save_best.h5
# Epoch 6/150
# 20/20 [==============================] - 8s 380ms/step - loss: 1.2824 - accuracy: 0.3227 - val_loss: 1.7750 - val_accuracy: 0.3526
#
# Epoch 00006: val_loss improved from 2.01330 to 1.77498, saving model to save_best.h5
# Epoch 7/150
# 20/20 [==============================] - 8s 389ms/step - loss: 1.2913 - accuracy: 0.3241 - val_loss: 1.6603 - val_accuracy: 0.3498
#
# Epoch 00007: val_loss improved from 1.77498 to 1.66026, saving model to save_best.h5
# Epoch 8/150
# 20/20 [==============================] - 8s 384ms/step - loss: 1.2582 - accuracy: 0.3250 - val_loss: 1.7960 - val_accuracy: 0.3146
#
# Epoch 00008: val_loss did not improve from 1.66026
# Epoch 9/150
# 20/20 [==============================] - 8s 388ms/step - loss: 1.2263 - accuracy: 0.3286 - val_loss: 1.2504 - val_accuracy: 0.3464
#
# Epoch 00009: val_loss improved from 1.66026 to 1.25039, saving model to save_best.h5
# Epoch 10/150
# 20/20 [==============================] - 8s 383ms/step - loss: 1.2216 - accuracy: 0.3287 - val_loss: 1.4321 - val_accuracy: 0.3170
#
# Epoch 00010: val_loss did not improve from 1.25039
# Epoch 11/150
# 20/20 [==============================] - 8s 392ms/step - loss: 1.2345 - accuracy: 0.3303 - val_loss: 1.3895 - val_accuracy: 0.3522
#
# Epoch 00011: val_loss did not improve from 1.25039
# Epoch 12/150
# 20/20 [==============================] - 8s 380ms/step - loss: 1.2090 - accuracy: 0.3293 - val_loss: 2.1913 - val_accuracy: 0.3485
#
# Epoch 00012: val_loss did not improve from 1.25039
# Epoch 13/150
# 20/20 [==============================] - 8s 389ms/step - loss: 1.1846 - accuracy: 0.3278 - val_loss: 1.1187 - val_accuracy: 0.3237
#
# Epoch 00013: val_loss improved from 1.25039 to 1.11874, saving model to save_best.h5
# Epoch 14/150
# 20/20 [==============================] - 8s 379ms/step - loss: 1.1583 - accuracy: 0.3350 - val_loss: 1.2014 - val_accuracy: 0.3124
#
# Epoch 00014: val_loss did not improve from 1.11874
# Epoch 15/150
# 20/20 [==============================] - 8s 385ms/step - loss: 1.1822 - accuracy: 0.3296 - val_loss: 1.7109 - val_accuracy: 0.1871
#
# Epoch 00015: val_loss did not improve from 1.11874
# Epoch 16/150
# 20/20 [==============================] - 8s 388ms/step - loss: 1.1554 - accuracy: 0.3317 - val_loss: 1.8809 - val_accuracy: 0.2517
#
# Epoch 00016: val_loss did not improve from 1.11874
# Epoch 17/150
# 20/20 [==============================] - 8s 388ms/step - loss: 1.1049 - accuracy: 0.3372 - val_loss: 2.3474 - val_accuracy: 0.2062
#
# Epoch 00017: val_loss did not improve from 1.11874
# Epoch 18/150
# 20/20 [==============================] - 8s 382ms/step - loss: 1.1361 - accuracy: 0.3354 - val_loss: 1.4190 - val_accuracy: 0.2974
#
# Epoch 00018: val_loss did not improve from 1.11874
# Epoch 19/150
# 20/20 [==============================] - 8s 389ms/step - loss: 1.1296 - accuracy: 0.3379 - val_loss: 1.6588 - val_accuracy: 0.3129
#
# Epoch 00019: val_loss did not improve from 1.11874
# Epoch 20/150
# 20/20 [==============================] - 8s 383ms/step - loss: 1.0963 - accuracy: 0.3377 - val_loss: 1.5744 - val_accuracy: 0.3253
#
# Epoch 00020: val_loss did not improve from 1.11874
# Epoch 21/150
# 20/20 [==============================] - 8s 384ms/step - loss: 1.0908 - accuracy: 0.3369 - val_loss: 1.2275 - val_accuracy: 0.3231
#
# Epoch 00021: val_loss did not improve from 1.11874
# Epoch 22/150
# 20/20 [==============================] - 8s 377ms/step - loss: 1.0844 - accuracy: 0.3397 - val_loss: 1.6551 - val_accuracy: 0.3394
#
# Epoch 00022: val_loss did not improve from 1.11874
# Epoch 23/150
# 20/20 [==============================] - 8s 387ms/step - loss: 1.0715 - accuracy: 0.3390 - val_loss: 1.0820 - val_accuracy: 0.3289
#
# Epoch 00023: val_loss improved from 1.11874 to 1.08200, saving model to save_best.h5
# Epoch 24/150
# 20/20 [==============================] - 8s 382ms/step - loss: 1.0637 - accuracy: 0.3389 - val_loss: 1.2435 - val_accuracy: 0.3376
#
# Epoch 00024: val_loss did not improve from 1.08200
# Epoch 25/150
# 20/20 [==============================] - 8s 390ms/step - loss: 1.0466 - accuracy: 0.3416 - val_loss: 1.3379 - val_accuracy: 0.3154
#
# Epoch 00025: val_loss did not improve from 1.08200
# Epoch 26/150
# 20/20 [==============================] - 8s 383ms/step - loss: 1.0244 - accuracy: 0.3426 - val_loss: 1.5605 - val_accuracy: 0.3371
#
# Epoch 00026: val_loss did not improve from 1.08200
# Epoch 27/150
# 20/20 [==============================] - 8s 384ms/step - loss: 1.0262 - accuracy: 0.3427 - val_loss: 1.1636 - val_accuracy: 0.3185
#
# Epoch 00027: val_loss did not improve from 1.08200
# Epoch 28/150
# 20/20 [==============================] - 8s 385ms/step - loss: 0.9959 - accuracy: 0.3479 - val_loss: 0.9190 - val_accuracy: 0.3705
#
# Epoch 00028: val_loss improved from 1.08200 to 0.91904, saving model to save_best.h5
# Epoch 29/150
# 20/20 [==============================] - 8s 384ms/step - loss: 0.9457 - accuracy: 0.3475 - val_loss: 1.1327 - val_accuracy: 0.3348
#
# Epoch 00029: val_loss did not improve from 0.91904
# Epoch 30/150
# 20/20 [==============================] - 8s 392ms/step - loss: 0.9522 - accuracy: 0.3470 - val_loss: 1.1994 - val_accuracy: 0.3788
#
# Epoch 00030: val_loss did not improve from 0.91904
# Epoch 31/150
# 20/20 [==============================] - 8s 385ms/step - loss: 0.9505 - accuracy: 0.3495 - val_loss: 1.2733 - val_accuracy: 0.3648
#
# Epoch 00031: val_loss did not improve from 0.91904
# Epoch 32/150
# 20/20 [==============================] - 8s 385ms/step - loss: 0.9331 - accuracy: 0.3502 - val_loss: 0.8258 - val_accuracy: 0.3562
#
# Epoch 00032: val_loss improved from 0.91904 to 0.82584, saving model to save_best.h5
# Epoch 33/150
# 20/20 [==============================] - 8s 384ms/step - loss: 0.8985 - accuracy: 0.3524 - val_loss: 0.9580 - val_accuracy: 0.3559
#
# Epoch 00033: val_loss did not improve from 0.82584
# Epoch 34/150
# 20/20 [==============================] - 8s 395ms/step - loss: 0.8663 - accuracy: 0.3568 - val_loss: 0.9441 - val_accuracy: 0.3559
#
# Epoch 00034: val_loss did not improve from 0.82584
# Epoch 35/150
# 20/20 [==============================] - 8s 388ms/step - loss: 0.8737 - accuracy: 0.3555 - val_loss: 0.9873 - val_accuracy: 0.3442
#
# Epoch 00035: val_loss did not improve from 0.82584
# Epoch 36/150
# 20/20 [==============================] - 8s 391ms/step - loss: 0.8820 - accuracy: 0.3557 - val_loss: 0.8917 - val_accuracy: 0.3822
#
# Epoch 00036: val_loss did not improve from 0.82584
# Epoch 37/150
# 20/20 [==============================] - 8s 398ms/step - loss: 0.8727 - accuracy: 0.3562 - val_loss: 1.3731 - val_accuracy: 0.3555
#
# Epoch 00037: val_loss did not improve from 0.82584
# Epoch 38/150
# 20/20 [==============================] - 8s 389ms/step - loss: 0.8696 - accuracy: 0.3568 - val_loss: 0.8946 - val_accuracy: 0.3482
#
# Epoch 00038: val_loss did not improve from 0.82584
# Epoch 39/150
# 20/20 [==============================] - 8s 387ms/step - loss: 0.8224 - accuracy: 0.3581 - val_loss: 0.8820 - val_accuracy: 0.3359
#
# Epoch 00039: val_loss did not improve from 0.82584
# Epoch 40/150
# 20/20 [==============================] - 8s 384ms/step - loss: 0.8220 - accuracy: 0.3611 - val_loss: 0.9315 - val_accuracy: 0.3443
# Epoch 00040: val_loss did not improve from 0.82584
# Epoch 41/150
# 20/20 [==============================] - 8s 386ms/step - loss: 0.7903 - accuracy: 0.3622 - val_loss: 0.9136 - val_accuracy: 0.3446
#
# Epoch 00041: val_loss did not improve from 0.82584
# Epoch 42/150
# 20/20 [==============================] - 8s 397ms/step - loss: 0.8112 - accuracy: 0.3624 - val_loss: 1.0884 - val_accuracy: 0.3690
#
# Epoch 00042: val_loss did not improve from 0.82584
# Epoch 43/150
# 20/20 [==============================] - 8s 385ms/step - loss: 0.7837 - accuracy: 0.3637 - val_loss: 0.8181 - val_accuracy: 0.3749
#
# Epoch 00043: val_loss improved from 0.82584 to 0.81810, saving model to save_best.h5
# Epoch 44/150
# 20/20 [==============================] - 8s 396ms/step - loss: 0.7505 - accuracy: 0.3660 - val_loss: 0.9752 - val_accuracy: 0.3304
#
# Epoch 00044: val_loss did not improve from 0.81810
# Epoch 45/150
# 20/20 [==============================] - 8s 382ms/step - loss: 0.7464 - accuracy: 0.3658 - val_loss: 1.0610 - val_accuracy: 0.3378
#
# Epoch 00045: val_loss did not improve from 0.81810
# Epoch 46/150
# 20/20 [==============================] - 8s 398ms/step - loss: 0.7487 - accuracy: 0.3668 - val_loss: 0.8319 - val_accuracy: 0.3381
#
# Epoch 00046: val_loss did not improve from 0.81810
# Epoch 47/150
# 20/20 [==============================] - 8s 384ms/step - loss: 0.7103 - accuracy: 0.3685 - val_loss: 0.8926 - val_accuracy: 0.3436
#
# Epoch 00047: val_loss did not improve from 0.81810
# Epoch 48/150
# 20/20 [==============================] - 7s 365ms/step - loss: 0.7279 - accuracy: 0.3690 - val_loss: 0.9348 - val_accuracy: 0.3558
#
# Epoch 00048: val_loss did not improve from 0.81810
# Epoch 49/150
# 20/20 [==============================] - 7s 368ms/step - loss: 0.7073 - accuracy: 0.3695 - val_loss: 1.0314 - val_accuracy: 0.3815
#
# Epoch 00049: val_loss did not improve from 0.81810
# Epoch 50/150
# 20/20 [==============================] - 7s 369ms/step - loss: 0.6882 - accuracy: 0.3713 - val_loss: 0.8530 - val_accuracy: 0.3449
#
# Epoch 00050: val_loss did not improve from 0.81810
# Epoch 51/150
# 20/20 [==============================] - 7s 365ms/step - loss: 0.6822 - accuracy: 0.3704 - val_loss: 0.7046 - val_accuracy: 0.3762
#
# Epoch 00051: val_loss improved from 0.81810 to 0.70455, saving model to save_best.h5
# Epoch 52/150
# 20/20 [==============================] - 8s 370ms/step - loss: 0.6648 - accuracy: 0.3719 - val_loss: 0.8246 - val_accuracy: 0.3660
#
# Epoch 00052: val_loss did not improve from 0.70455
# Epoch 53/150
# 20/20 [==============================] - 7s 364ms/step - loss: 0.6585 - accuracy: 0.3732 - val_loss: 0.8218 - val_accuracy: 0.3772
#
# Epoch 00053: val_loss did not improve from 0.70455
# Epoch 54/150
# 20/20 [==============================] - 8s 372ms/step - loss: 0.6572 - accuracy: 0.3736 - val_loss: 0.5895 - val_accuracy: 0.3536
#
# Epoch 00054: val_loss improved from 0.70455 to 0.58953, saving model to save_best.h5
# Epoch 55/150
# 20/20 [==============================] - 7s 369ms/step - loss: 0.6242 - accuracy: 0.3762 - val_loss: 0.5489 - val_accuracy: 0.3615
#
# Epoch 00055: val_loss improved from 0.58953 to 0.54889, saving model to save_best.h5
# Epoch 56/150
# 20/20 [==============================] - 7s 367ms/step - loss: 0.6251 - accuracy: 0.3756 - val_loss: 0.6780 - val_accuracy: 0.3631
#
# Epoch 00056: val_loss did not improve from 0.54889
# Epoch 57/150
# 20/20 [==============================] - 7s 363ms/step - loss: 0.6276 - accuracy: 0.3751 - val_loss: 0.7630 - val_accuracy: 0.3772
#
# Epoch 00057: val_loss did not improve from 0.54889
# Epoch 58/150
# 20/20 [==============================] - 8s 370ms/step - loss: 0.6119 - accuracy: 0.3749 - val_loss: 0.8104 - val_accuracy: 0.3863
#
# Epoch 00058: val_loss did not improve from 0.54889
# Epoch 59/150
# 20/20 [==============================] - 7s 367ms/step - loss: 0.6257 - accuracy: 0.3770 - val_loss: 0.6506 - val_accuracy: 0.4002
#
# Epoch 00059: val_loss did not improve from 0.54889
# Epoch 60/150
# 20/20 [==============================] - 7s 365ms/step - loss: 0.6248 - accuracy: 0.3776 - val_loss: 0.5429 - val_accuracy: 0.3691
#
# Epoch 00060: val_loss improved from 0.54889 to 0.54285, saving model to save_best.h5
# Epoch 61/150
# 20/20 [==============================] - 7s 366ms/step - loss: 0.6170 - accuracy: 0.3773 - val_loss: 0.5721 - val_accuracy: 0.3784
#
# Epoch 00061: val_loss did not improve from 0.54285
# Epoch 62/150
# 20/20 [==============================] - 7s 366ms/step - loss: 0.5983 - accuracy: 0.3784 - val_loss: 0.6120 - val_accuracy: 0.3658
#
# Epoch 00062: val_loss did not improve from 0.54285
# Epoch 63/150
# 20/20 [==============================] - 8s 378ms/step - loss: 0.5921 - accuracy: 0.3792 - val_loss: 0.5851 - val_accuracy: 0.3626
#
# Epoch 00063: val_loss did not improve from 0.54285
# Epoch 64/150
# 20/20 [==============================] - 8s 370ms/step - loss: 0.5820 - accuracy: 0.3795 - val_loss: 0.5271 - val_accuracy: 0.3695
#
# Epoch 00064: val_loss improved from 0.54285 to 0.52714, saving model to save_best.h5
# Epoch 65/150
# 20/20 [==============================] - 8s 378ms/step - loss: 0.5690 - accuracy: 0.3807 - val_loss: 0.6426 - val_accuracy: 0.3760
#
# Epoch 00065: val_loss did not improve from 0.52714
# Epoch 66/150
# 20/20 [==============================] - 8s 378ms/step - loss: 0.5696 - accuracy: 0.3803 - val_loss: 0.7134 - val_accuracy: 0.4078
#
# Epoch 00066: val_loss did not improve from 0.52714
# Epoch 67/150
# 20/20 [==============================] - 8s 380ms/step - loss: 0.5647 - accuracy: 0.3799 - val_loss: 0.6202 - val_accuracy: 0.3660
#
# Epoch 00067: val_loss did not improve from 0.52714
# Epoch 68/150
# 20/20 [==============================] - 8s 372ms/step - loss: 0.5611 - accuracy: 0.3823 - val_loss: 0.5119 - val_accuracy: 0.3698
#
# Epoch 00068: val_loss improved from 0.52714 to 0.51190, saving model to save_best.h5
# Epoch 69/150
# 20/20 [==============================] - 8s 385ms/step - loss: 0.5536 - accuracy: 0.3819 - val_loss: 0.5774 - val_accuracy: 0.3830
#
# Epoch 00069: val_loss did not improve from 0.51190
# Epoch 70/150
# 20/20 [==============================] - 8s 379ms/step - loss: 0.5381 - accuracy: 0.3820 - val_loss: 0.5202 - val_accuracy: 0.3778
#
# Epoch 00070: val_loss did not improve from 0.51190
# Epoch 71/150
# 20/20 [==============================] - 8s 384ms/step - loss: 0.5382 - accuracy: 0.3829 - val_loss: 0.5805 - val_accuracy: 0.3844
#
# Epoch 00071: val_loss did not improve from 0.51190
# Epoch 72/150
# 20/20 [==============================] - 8s 371ms/step - loss: 0.5518 - accuracy: 0.3820 - val_loss: 0.6818 - val_accuracy: 0.4047
#
# Epoch 00072: val_loss did not improve from 0.51190
# Epoch 73/150
# 20/20 [==============================] - 8s 377ms/step - loss: 0.5353 - accuracy: 0.3838 - val_loss: 0.6751 - val_accuracy: 0.4084
#
# Epoch 00073: val_loss did not improve from 0.51190
# Epoch 74/150
# 20/20 [==============================] - 8s 383ms/step - loss: 0.5189 - accuracy: 0.3845 - val_loss: 0.5197 - val_accuracy: 0.3860
#
# Epoch 00074: val_loss did not improve from 0.51190
# Epoch 75/150
# 20/20 [==============================] - 8s 394ms/step - loss: 0.5351 - accuracy: 0.3834 - val_loss: 0.5395 - val_accuracy: 0.3852
#
# Epoch 00075: val_loss did not improve from 0.51190
# Epoch 76/150
# 20/20 [==============================] - 8s 398ms/step - loss: 0.5149 - accuracy: 0.3836 - val_loss: 0.5538 - val_accuracy: 0.3776
#
# Epoch 00076: val_loss did not improve from 0.51190
# Epoch 77/150
# 20/20 [==============================] - 8s 394ms/step - loss: 0.5176 - accuracy: 0.3841 - val_loss: 0.4458 - val_accuracy: 0.3683
#
# Epoch 00077: val_loss improved from 0.51190 to 0.44578, saving model to save_best.h5
# Epoch 78/150
# 20/20 [==============================] - 8s 391ms/step - loss: 0.4932 - accuracy: 0.3852 - val_loss: 0.4235 - val_accuracy: 0.3671
#
# Epoch 00078: val_loss improved from 0.44578 to 0.42345, saving model to save_best.h5
# Epoch 79/150
# 20/20 [==============================] - 8s 393ms/step - loss: 0.4923 - accuracy: 0.3863 - val_loss: 0.5859 - val_accuracy: 0.3779
#
# Epoch 00079: val_loss did not improve from 0.42345
# Epoch 80/150
# 20/20 [==============================] - 8s 387ms/step - loss: 0.4946 - accuracy: 0.3864 - val_loss: 0.4583 - val_accuracy: 0.3799
#
# Epoch 00080: val_loss did not improve from 0.42345
# Epoch 81/150
# 20/20 [==============================] - 8s 387ms/step - loss: 0.5016 - accuracy: 0.3870 - val_loss: 0.5760 - val_accuracy: 0.3926
#
# Epoch 00081: val_loss did not improve from 0.42345
# Epoch 82/150
# 20/20 [==============================] - 8s 385ms/step - loss: 0.5000 - accuracy: 0.3853 - val_loss: 0.4379 - val_accuracy: 0.3930
#
# Epoch 00082: val_loss did not improve from 0.42345
# Epoch 83/150
# 20/20 [==============================] - 8s 392ms/step - loss: 0.4976 - accuracy: 0.3858 - val_loss: 0.5376 - val_accuracy: 0.3756
#
# Epoch 00083: val_loss did not improve from 0.42345
# Epoch 84/150
# 20/20 [==============================] - 8s 391ms/step - loss: 0.5081 - accuracy: 0.3863 - val_loss: 0.4691 - val_accuracy: 0.3826
#
# Epoch 00084: val_loss did not improve from 0.42345
# Epoch 85/150
# 20/20 [==============================] - 8s 393ms/step - loss: 0.5048 - accuracy: 0.3859 - val_loss: 0.4523 - val_accuracy: 0.3706
#
# Epoch 00085: val_loss did not improve from 0.42345
# Epoch 86/150
# 20/20 [==============================] - 8s 392ms/step - loss: 0.4763 - accuracy: 0.3880 - val_loss: 0.5437 - val_accuracy: 0.3981
#
# Epoch 00086: val_loss did not improve from 0.42345
# Epoch 87/150
# 20/20 [==============================] - 8s 392ms/step - loss: 0.4710 - accuracy: 0.3887 - val_loss: 0.5640 - val_accuracy: 0.4080
#
# Epoch 00087: val_loss did not improve from 0.42345
# Epoch 88/150
# 20/20 [==============================] - 8s 385ms/step - loss: 0.4640 - accuracy: 0.3889 - val_loss: 0.5003 - val_accuracy: 0.3831
#
# Epoch 00088: val_loss did not improve from 0.42345
# Epoch 89/150
# 20/20 [==============================] - 8s 391ms/step - loss: 0.4672 - accuracy: 0.3863 - val_loss: 0.4680 - val_accuracy: 0.3945
#
# Epoch 00089: val_loss did not improve from 0.42345
# Epoch 90/150
# 20/20 [==============================] - 8s 385ms/step - loss: 0.4612 - accuracy: 0.3889 - val_loss: 0.4811 - val_accuracy: 0.3858
#
# Epoch 00090: val_loss did not improve from 0.42345
# Epoch 91/150
# 20/20 [==============================] - 8s 393ms/step - loss: 0.4643 - accuracy: 0.3885 - val_loss: 0.4393 - val_accuracy: 0.3901
#
# Epoch 00091: val_loss did not improve from 0.42345
# Epoch 92/150
# 20/20 [==============================] - 8s 387ms/step - loss: 0.4472 - accuracy: 0.3900 - val_loss: 0.5585 - val_accuracy: 0.3872
#
# Epoch 00092: val_loss did not improve from 0.42345
# Epoch 93/150
# 20/20 [==============================] - 8s 393ms/step - loss: 0.4447 - accuracy: 0.3899 - val_loss: 0.4314 - val_accuracy: 0.3794
#
# Epoch 00093: val_loss did not improve from 0.42345
# Epoch 94/150
# 20/20 [==============================] - 8s 384ms/step - loss: 0.4415 - accuracy: 0.3887 - val_loss: 0.4757 - val_accuracy: 0.3996
#
# Epoch 00094: val_loss did not improve from 0.42345
# Epoch 95/150
# 20/20 [==============================] - 8s 393ms/step - loss: 0.4409 - accuracy: 0.3901 - val_loss: 0.4124 - val_accuracy: 0.3950
#
# Epoch 00095: val_loss improved from 0.42345 to 0.41245, saving model to save_best.h5
# Epoch 96/150
# 20/20 [==============================] - 8s 396ms/step - loss: 0.4452 - accuracy: 0.3891 - val_loss: 0.4963 - val_accuracy: 0.3790
#
# Epoch 00096: val_loss did not improve from 0.41245
# Epoch 97/150
# 20/20 [==============================] - 8s 393ms/step - loss: 0.4628 - accuracy: 0.3893 - val_loss: 0.4617 - val_accuracy: 0.3747
#
# Epoch 00097: val_loss did not improve from 0.41245
# Epoch 98/150
# 20/20 [==============================] - 8s 390ms/step - loss: 0.4412 - accuracy: 0.3882 - val_loss: 0.4677 - val_accuracy: 0.3932
#
# Epoch 00098: val_loss did not improve from 0.41245
# Epoch 99/150
# 20/20 [==============================] - 8s 396ms/step - loss: 0.4309 - accuracy: 0.3911 - val_loss: 0.4597 - val_accuracy: 0.4213
#
# Epoch 00099: val_loss did not improve from 0.41245
# Epoch 100/150
# 20/20 [==============================] - 8s 390ms/step - loss: 0.4339 - accuracy: 0.3888 - val_loss: 0.4796 - val_accuracy: 0.4145
#
# Epoch 00100: val_loss did not improve from 0.41245
# Epoch 101/150
# 20/20 [==============================] - 8s 398ms/step - loss: 0.4170 - accuracy: 0.3902 - val_loss: 0.4162 - val_accuracy: 0.3828
#
# Epoch 00101: val_loss did not improve from 0.41245
# Epoch 102/150
# 20/20 [==============================] - 8s 383ms/step - loss: 0.4177 - accuracy: 0.3912 - val_loss: 0.4209 - val_accuracy: 0.3834
#
# Epoch 00102: val_loss did not improve from 0.41245
# Epoch 103/150
# 20/20 [==============================] - 8s 387ms/step - loss: 0.4254 - accuracy: 0.3898 - val_loss: 0.4550 - val_accuracy: 0.3808
#
# Epoch 00103: val_loss did not improve from 0.41245
# Epoch 104/150
# 20/20 [==============================] - 8s 384ms/step - loss: 0.4256 - accuracy: 0.3903 - val_loss: 0.4406 - val_accuracy: 0.3891
#
# Epoch 00104: val_loss did not improve from 0.41245
# Epoch 105/150
# 20/20 [==============================] - 8s 390ms/step - loss: 0.4157 - accuracy: 0.3914 - val_loss: 0.4301 - val_accuracy: 0.3854
#
# Epoch 00105: val_loss did not improve from 0.41245
# Epoch 106/150
# 20/20 [==============================] - 8s 382ms/step - loss: 0.4210 - accuracy: 0.3909 - val_loss: 0.4179 - val_accuracy: 0.3941
#
# Epoch 00106: val_loss did not improve from 0.41245
# Epoch 107/150
# 20/20 [==============================] - 8s 390ms/step - loss: 0.4004 - accuracy: 0.3922 - val_loss: 0.3835 - val_accuracy: 0.3783
#
# Epoch 00107: val_loss improved from 0.41245 to 0.38349, saving model to save_best.h5
# Epoch 108/150
# 20/20 [==============================] - 8s 390ms/step - loss: 0.4048 - accuracy: 0.3915 - val_loss: 0.4157 - val_accuracy: 0.3872
#
# Epoch 00108: val_loss did not improve from 0.38349
# Epoch 109/150
# 20/20 [==============================] - 8s 386ms/step - loss: 0.4074 - accuracy: 0.3923 - val_loss: 0.4005 - val_accuracy: 0.3976
#
# Epoch 00109: val_loss did not improve from 0.38349
# Epoch 110/150
# 20/20 [==============================] - 8s 395ms/step - loss: 0.4015 - accuracy: 0.3922 - val_loss: 0.3781 - val_accuracy: 0.3916
#
# Epoch 00110: val_loss improved from 0.38349 to 0.37813, saving model to save_best.h5
# Epoch 111/150
# 20/20 [==============================] - 8s 396ms/step - loss: 0.4034 - accuracy: 0.3909 - val_loss: 0.4676 - val_accuracy: 0.3907
#
# Epoch 00111: val_loss did not improve from 0.37813
# Epoch 112/150
# 20/20 [==============================] - 8s 388ms/step - loss: 0.3940 - accuracy: 0.3924 - val_loss: 0.4566 - val_accuracy: 0.3937
#
# Epoch 00112: val_loss did not improve from 0.37813
# Epoch 113/150
# 20/20 [==============================] - 8s 401ms/step - loss: 0.4015 - accuracy: 0.3928 - val_loss: 0.4172 - val_accuracy: 0.3903
#
# Epoch 00113: val_loss did not improve from 0.37813
# Epoch 114/150
# 20/20 [==============================] - 8s 395ms/step - loss: 0.3967 - accuracy: 0.3921 - val_loss: 0.3900 - val_accuracy: 0.3720
#
# Epoch 00114: val_loss did not improve from 0.37813
# Epoch 115/150
# 20/20 [==============================] - 8s 400ms/step - loss: 0.3912 - accuracy: 0.3909 - val_loss: 0.4066 - val_accuracy: 0.3866
#
# Epoch 00115: val_loss did not improve from 0.37813
# Epoch 116/150
# 20/20 [==============================] - 8s 387ms/step - loss: 0.4044 - accuracy: 0.3906 - val_loss: 0.4389 - val_accuracy: 0.3937
#
# Epoch 00116: val_loss did not improve from 0.37813
# Epoch 117/150
# 20/20 [==============================] - 8s 399ms/step - loss: 0.4020 - accuracy: 0.3899 - val_loss: 0.3922 - val_accuracy: 0.3870
#
# Epoch 00117: val_loss did not improve from 0.37813
# Epoch 118/150
# 20/20 [==============================] - 8s 394ms/step - loss: 0.3856 - accuracy: 0.3924 - val_loss: 0.3763 - val_accuracy: 0.4025
#
# Epoch 00118: val_loss improved from 0.37813 to 0.37632, saving model to save_best.h5
# Epoch 119/150
# 20/20 [==============================] - 8s 392ms/step - loss: 0.3933 - accuracy: 0.3928 - val_loss: 0.4487 - val_accuracy: 0.4045
#
# Epoch 00119: val_loss did not improve from 0.37632
# Epoch 120/150
# 20/20 [==============================] - 8s 383ms/step - loss: 0.3931 - accuracy: 0.3919 - val_loss: 0.3673 - val_accuracy: 0.3809
#
# Epoch 00120: val_loss improved from 0.37632 to 0.36732, saving model to save_best.h5
# Epoch 121/150
# 20/20 [==============================] - 8s 398ms/step - loss: 0.3990 - accuracy: 0.3926 - val_loss: 0.3828 - val_accuracy: 0.3790
#
# Epoch 00121: val_loss did not improve from 0.36732
# Epoch 122/150
# 20/20 [==============================] - 8s 393ms/step - loss: 0.3787 - accuracy: 0.3923 - val_loss: 0.3460 - val_accuracy: 0.3876
#
# Epoch 00122: val_loss improved from 0.36732 to 0.34597, saving model to save_best.h5
# Epoch 123/150
# 20/20 [==============================] - 8s 392ms/step - loss: 0.3733 - accuracy: 0.3933 - val_loss: 0.3764 - val_accuracy: 0.3905
#
# Epoch 00123: val_loss did not improve from 0.34597
# Epoch 124/150
# 20/20 [==============================] - 8s 394ms/step - loss: 0.3804 - accuracy: 0.3939 - val_loss: 0.3521 - val_accuracy: 0.3895
#
# Epoch 00124: val_loss did not improve from 0.34597
# Epoch 125/150
# 20/20 [==============================] - 8s 393ms/step - loss: 0.3733 - accuracy: 0.3925 - val_loss: 0.3794 - val_accuracy: 0.4004
#
# Epoch 00125: val_loss did not improve from 0.34597
# Epoch 126/150
# 20/20 [==============================] - 8s 387ms/step - loss: 0.3816 - accuracy: 0.3917 - val_loss: 0.4562 - val_accuracy: 0.4013
#
# Epoch 00126: val_loss did not improve from 0.34597
# Epoch 127/150
# 20/20 [==============================] - 8s 395ms/step - loss: 0.3895 - accuracy: 0.3925 - val_loss: 0.3212 - val_accuracy: 0.3689
#
# Epoch 00127: val_loss improved from 0.34597 to 0.32125, saving model to save_best.h5
# Epoch 128/150
# 20/20 [==============================] - 8s 393ms/step - loss: 0.3726 - accuracy: 0.3935 - val_loss: 0.3587 - val_accuracy: 0.3876
#
# Epoch 00128: val_loss did not improve from 0.32125
# Epoch 129/150
# 20/20 [==============================] - 8s 390ms/step - loss: 0.3552 - accuracy: 0.3929 - val_loss: 0.4496 - val_accuracy: 0.3932
#
# Epoch 00129: val_loss did not improve from 0.32125
# Epoch 130/150
# 20/20 [==============================] - 8s 390ms/step - loss: 0.3590 - accuracy: 0.3932 - val_loss: 0.3421 - val_accuracy: 0.4001
#
# Epoch 00130: val_loss did not improve from 0.32125
# Epoch 131/150
# 20/20 [==============================] - 8s 396ms/step - loss: 0.3599 - accuracy: 0.3936 - val_loss: 0.3946 - val_accuracy: 0.4136
#
# Epoch 00131: val_loss did not improve from 0.32125
# Epoch 132/150
# 20/20 [==============================] - 8s 396ms/step - loss: 0.3561 - accuracy: 0.3938 - val_loss: 0.3321 - val_accuracy: 0.4062
#
# Epoch 00132: val_loss did not improve from 0.32125
# Epoch 133/150
# 20/20 [==============================] - 9s 430ms/step - loss: 0.3575 - accuracy: 0.3937 - val_loss: 0.4566 - val_accuracy: 0.4096
#
# Epoch 00133: val_loss did not improve from 0.32125
# Epoch 134/150
# 20/20 [==============================] - 8s 394ms/step - loss: 0.3632 - accuracy: 0.3932 - val_loss: 0.3796 - val_accuracy: 0.3722
#
# Epoch 00134: val_loss did not improve from 0.32125
# Epoch 135/150
# 20/20 [==============================] - 8s 392ms/step - loss: 0.3642 - accuracy: 0.3934 - val_loss: 0.4382 - val_accuracy: 0.3783
#
# Epoch 00135: val_loss did not improve from 0.32125
# Epoch 136/150
# 20/20 [==============================] - 8s 387ms/step - loss: 0.3608 - accuracy: 0.3931 - val_loss: 0.3989 - val_accuracy: 0.3946
#
# Epoch 00136: val_loss did not improve from 0.32125
# Epoch 137/150
# 20/20 [==============================] - 8s 390ms/step - loss: 0.3546 - accuracy: 0.3951 - val_loss: 0.3805 - val_accuracy: 0.3815
#
# Epoch 00137: val_loss did not improve from 0.32125
# Epoch 138/150
# 20/20 [==============================] - 8s 382ms/step - loss: 0.3529 - accuracy: 0.3939 - val_loss: 0.3957 - val_accuracy: 0.4201
#
# Epoch 00138: val_loss did not improve from 0.32125
# Epoch 139/150
# 20/20 [==============================] - 8s 395ms/step - loss: 0.3689 - accuracy: 0.3939 - val_loss: 0.3857 - val_accuracy: 0.3815
#
# Epoch 00139: val_loss did not improve from 0.32125
# Epoch 140/150
# 20/20 [==============================] - 8s 388ms/step - loss: 0.3632 - accuracy: 0.3942 - val_loss: 0.4192 - val_accuracy: 0.4311
#
# Epoch 00140: val_loss did not improve from 0.32125
# Epoch 141/150
# 20/20 [==============================] - 8s 394ms/step - loss: 0.3557 - accuracy: 0.3933 - val_loss: 0.3562 - val_accuracy: 0.3921
#
# Epoch 00141: val_loss did not improve from 0.32125
# Epoch 142/150
# 20/20 [==============================] - 8s 392ms/step - loss: 0.3542 - accuracy: 0.3954 - val_loss: 0.3986 - val_accuracy: 0.4003
#
# Epoch 00142: val_loss did not improve from 0.32125
# Epoch 143/150
# 20/20 [==============================] - 8s 418ms/step - loss: 0.3502 - accuracy: 0.3950 - val_loss: 0.2957 - val_accuracy: 0.3894
#
# Epoch 00143: val_loss improved from 0.32125 to 0.29572, saving model to save_best.h5
# Epoch 144/150
# 20/20 [==============================] - 8s 387ms/step - loss: 0.3482 - accuracy: 0.3953 - val_loss: 0.3826 - val_accuracy: 0.3854
#
# Epoch 00144: val_loss did not improve from 0.29572
# Epoch 145/150
# 20/20 [==============================] - 8s 399ms/step - loss: 0.3445 - accuracy: 0.3945 - val_loss: 0.3961 - val_accuracy: 0.3880
#
# Epoch 00145: val_loss did not improve from 0.29572
# Epoch 146/150
# 20/20 [==============================] - 8s 416ms/step - loss: 0.3367 - accuracy: 0.3946 - val_loss: 0.3460 - val_accuracy: 0.3912
#
# Epoch 00146: val_loss did not improve from 0.29572
# Epoch 147/150
# 20/20 [==============================] - 8s 401ms/step - loss: 0.3547 - accuracy: 0.3950 - val_loss: 0.3503 - val_accuracy: 0.4010
#
# Epoch 00147: val_loss did not improve from 0.29572
# Epoch 148/150
# 20/20 [==============================] - 8s 397ms/step - loss: 0.3458 - accuracy: 0.3941 - val_loss: 0.3235 - val_accuracy: 0.3845
#
# Epoch 00148: val_loss did not improve from 0.29572
# Epoch 149/150
# 20/20 [==============================] - 8s 413ms/step - loss: 0.3348 - accuracy: 0.3942 - val_loss: 0.3091 - val_accuracy: 0.3833
#
# Epoch 00149: val_loss did not improve from 0.29572
# Epoch 150/150
# 20/20 [==============================] - 8s 385ms/step - loss: 0.3403 - accuracy: 0.3942 - val_loss: 0.3425 - val_accuracy: 0.3883
#
# Epoch 00150: val_loss did not improve from 0.29572

# %%
model.load_weights('save_best.h5')

# %%
pd.DataFrame(history.history).plot(figsize=(8,5), logy=True)
plt.show()

# %%
# restore the best model
model.load_weights('save_best.h5')

# %%
plt.figure(figsize=(20,10))
for_test = next(iter(val_ds.take(1)))
for i in range(5):
    plt.subplot(5,3,3*i + 1),plt.imshow(np.exp(model.predict(for_test[0])[i,:,:,0])),plt.colorbar();
    plt.subplot(5,3,3*i + 2),plt.imshow(for_test[1][i].numpy()), plt.colorbar();
    plt.subplot(5,3,3*i + 3),plt.imshow(for_test[0][i].numpy());

# %%
list_ds_test = tf.data.Dataset.list_files('data_scene_flow/testing/image_2/*_10.png')
def process_path_test(file_path):
    image = tf.io.read_file(file_path)
    image = tf.image.decode_png(image)
    image = tf.image.convert_image_dtype(image, tf.float32)
    image = tf.image.resize(image, [192, 640])

    return image

test_ds = list_ds_test.map(process_path_test)
test_ds = test_ds.batch(5)

# %%
plt.figure(figsize=(20,10))
for_test = next(iter(test_ds.take(1)))
for i in range(5):
    plt.subplot(5,2,2*i + 1),plt.imshow(np.exp(model.predict(for_test)[i,:,:,0])),plt.colorbar();
    plt.subplot(5,2,2*i + 2),plt.imshow(for_test[i].numpy());
